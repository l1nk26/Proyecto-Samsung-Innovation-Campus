# %%
import procesado_de_datos as pdd
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./diabetes.csv')

#df = pdd.procesar(df)
#pdd.mostrar_datos(df)
#df.columns

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
d1 = pd.read_csv("diabetes_012_health_indicators_BRFSS2015.csv")
def analisis() :
    
    aux = list(d1.columns)
    for i in range(1,len(aux)) :
        plt.scatter(d1[aux[i]], d1['Diabetes_012'])  ## correlacion pero con dispersion
        
        plt.xlabel(aux[i])
        plt.ylabel('Diabetes_012')
        plt.title('Análisis de Diabetes')
        plt.show()


#analisis()

# %%
mat_De_Corr = d1.corr()

plt.matshow(mat_De_Corr, cmap="bwr", label=["rojo"], vmin=-1, vmax=1)
plt.xlabel("Matriz de correlacion")
plt.xticks(range(22), d1.columns, rotation=90) # mostrar los nombres de las columnas
plt.yticks(range(22), d1.columns) # mostrar los nombres de las columnas
plt.colorbar() # barra de color del lado derecho
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
d1.corr().iloc[0,1:].describe()
# Out:
# count    21.000000
# mean      0.075405
# std       0.138900
# min      -0.171483
# 25%      -0.042192
# 50%       0.067546
# 75%       0.185026
# max       0.302587
# Name: Diabetes_012, dtype: float64

# %%
d2 = pd.read_csv("diabetes_binary_5050split_health_indicators_BRFSS2015.csv")
mat = d2.corr()
d2.corr().iloc[0,1:]


plt.matshow(mat, cmap="bwr", vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(range(22), d2.columns, rotation=90) # mostrar los nombres de las columnas
plt.yticks(range(22), d2.columns) # mostrar los nombres de las columnas
plt.show()

# %%
d3 = pd.read_csv("diabetes.csv")
mat = d2.corr()


plt.matshow(d3.corr(), cmap="bwr", vmin=-1, vmax=1)
plt.colorbar()
plt.xticks(range(len(d3.columns)), d3.columns, rotation=90) # mostrar los nombres de las columnas
plt.yticks(range(len(d3.columns)), d3.columns) # mostrar los nombres de las columnas
plt.show()
d3.corr().iloc[8,:8].describe()
# Out:
# count    8.000000
# mean     0.207968
# std      0.131204
# min      0.065068
# 25%      0.116599
# 50%      0.197871
# 75%      0.251941
# max      0.466581
# Name: Outcome, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt


Grafico_glucosa = d3.groupby(["Outcome"]).mean()

print(d3)
plt.title("Grafico de niveles de glucosa entre personas")
plt.xlabel("Sin diabetes | Con diabetes")
plt.ylabel("Glucosa")
plt.bar(Grafico_glucosa.index, Grafico_glucosa["Glucose"])
plt.show()



plt.title("Grafico de niveles de insulina entre personas")
plt.xlabel("Sin diabetes | Con diabetes")
plt.ylabel("Glucosa")
plt.bar(Grafico_glucosa.index, Grafico_glucosa["Insulin"])
plt.show()

f = list(d3.columns)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
d2.corr().iloc[0,1:].describe()

mat = d2.groupby(["Diabetes_binary"]).mean()

print(mat)

aux = list(mat.columns) 
print(aux)
for i in range(len(aux)):
    plt.bar(mat.index, mat[aux[i]])
    plt.title(f'Porcentaje de {aux[i]} en las personas dentro de un rango de 0 - {int(d2[aux[i]].max())}')
    plt.ylim(0, d2[aux[i]].max())
    plt.xticks(ticks=range(2), labels=['Sin diabetes','Con diabetes'])
    plt.show()
# Out:
#                    HighBP  HighChol  CholCheck        BMI    Smoker    Stroke  \
# Diabetes_binary
# 0.0              0.374243  0.381288   0.957336  27.769960  0.432326  0.031885
# 1.0              0.752674  0.670118   0.993182  31.944011  0.518220  0.092457
#
#                  HeartDiseaseorAttack  PhysActivity    Fruits   Veggies  ...  \
# Diabetes_binary                                                          ...
# 0.0                          0.072738      0.775533  0.638149  0.821140  ...
# 1.0                          0.222882      0.630538  0.585441  0.756408  ...
#
#                  AnyHealthcare  NoDocbcCost   GenHlth  MentHlth  PhysHlth  \
# Diabetes_binary
# 0.0                   0.950150     0.081961  2.383183  3.042268  3.666355
# 1.0                   0.959769     0.105868  3.290981  4.461806  7.954479
#
#                  DiffWalk       Sex       Age  Education    Income
# Diabetes_binary
# 0.0              0.134244  0.434872  7.789057   5.096390  6.186527
# ...

# %%
df2 = pd.read_csv("./diabetes_binary_5050split_health_indicators_BRFSS2015.csv")
df = pd.read_csv("diabetes.csv")

df3 = df[ df["Outcome"] == 1]
df4 = df[ df["Outcome"] == 0]
# los que tienen diabetes y los que no.

plt.boxplot([df3["Glucose"], df4["Glucose"]])

print(df3["Glucose"].describe())
print("*" * 100)
df4["Glucose"].describe(), "sin diabetes"
# Out:
# count    268.000000
# mean     141.257463
# std       31.939622
# min        0.000000
# 25%      119.000000
# 50%      140.000000
# 75%      167.000000
# max      199.000000
# Name: Glucose, dtype: float64
# ****************************************************************************************************
# (count    500.0000
#  mean     109.9800
#  std       26.1412
#  min        0.0000
#  25%       93.0000
#  50%      107.0000
#  75%      125.0000
#  max      197.0000
#  Name: Glucose, dtype: float64,
#  'sin diabetes')

# %%
#Promedio de glucosa por edad de los diabeticos.

Datos = pd.read_csv("diabetes.csv")

Datos_Diabetes = Datos[ Datos["Outcome"] == 1]

Datos_Diabetes = Datos_Diabetes.groupby(["Age"]).mean() # para dividir por edad

Datos_Diabetes.columns
plt.bar(Datos_Diabetes.index, Datos_Diabetes["Glucose"])
plt.show()

# %%
#Promedio de glucosa por edad de los NO diabeticos.

Datos = pd.read_csv("diabetes.csv")

Datos_Diabetes = Datos[ Datos["Outcome"] == 0]

Datos_Diabetes = Datos_Diabetes.groupby(["Age"]).mean() # para dividir por edad

Datos_Diabetes.columns
plt.bar(Datos_Diabetes.index, Datos_Diabetes["Glucose"])
plt.show()
